# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the trained model

# %%
model = tf.keras.models.load_model('/kaggle/input/drowsiness-tracking-2/SimpleModel.keras')
img_size = (128, 128)

# %%
video_path = "/kaggle/input/drowsiness-tracking-2/Dataset/Dataset/IMG_1494.mov"
cap = cv2.VideoCapture(video_path)

# %%
""" import cv2

def save_frame_as_image(video_path, frame_number, output_image_path):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Set the video position to the desired frame
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

    # Read the frame
    ret, frame = cap.read()

    if ret:
        # Save the frame as an image
        cv2.imwrite(output_image_path, frame)
        print(f"Frame {frame_number} saved as {output_image_path}")
    else:
        print(f"Frame {frame_number} could not be extracted!")

    # Release the video capture object
    cap.release()

# Usage
frame_number = 200  # Replace with the frame you want to extract
output_image_path = "frame_200.jpg"  # Output image path

save_frame_as_image(video_path, frame_number, output_image_path)
"""
# Out:
# ' import cv2\n\ndef save_frame_as_image(video_path, frame_number, output_image_path):\n    # Open the video file\n    cap = cv2.VideoCapture(video_path)\n\n    # Set the video position to the desired frame\n    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)\n\n    # Read the frame\n    ret, frame = cap.read()\n\n    if ret:\n        # Save the frame as an image\n        cv2.imwrite(output_image_path, frame)\n        print(f"Frame {frame_number} saved as {output_image_path}")\n    else:\n        print(f"Frame {frame_number} could not be extracted!")\n\n    # Release the video capture object\n    cap.release()\n\n# Usage\nframe_number = 200  # Replace with the frame you want to extract\noutput_image_path = "frame_200.jpg"  # Output image path\n\nsave_frame_as_image(video_path, frame_number, output_image_path)\n'

# %%
"""
img_array = cv2.imread('frame_200.jpg')
plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
"""
# Out:
# "\nimg_array = cv2.imread('frame_200.jpg')\nplt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))\n"

# %%
# !pip install facenet-pytorch opencv-python

# %%
# !pip install mtcnn
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.5 MB/s eta 0:00:00
# ...

# %%
"""
from mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt

# Create an MTCNN detector instance
detector = MTCNN

# Load the image
image_path = "frame_200.jpg"  # Replace with your image path
image = cv2.imread(image_path)

# Check if the image was loaded
if image is None:
    print("Error: Image not loaded. Check the file path.")
    exit()

# Convert to RGB (MTCNN expects RGB images)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
results = detector.detect_faces(image_rgb)
print(results)

# Loop through detected faces
for result in results:
    # Extract face bounding box
    x, y, width, height = result["box"]
    x2, y2 = x + width, y + height

    # Draw bounding box around the face
    cv2.rectangle(image, (x, y), (x2, y2), (255, 0, 0), 2)

    # Extract and draw facial keypoints
    keypoints = result["keypoints"]
    for key, point in keypoints.items():
        cv2.circle(image, tuple(point), 5, (0, 255, 0), -1)
        cv2.putText(image, key, tuple(point), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

# Convert back to RGB for visualization
image_bgr = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# Display the result
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
"""
# Out:
# '\nfrom mtcnn import MTCNN\nimport cv2\nimport matplotlib.pyplot as plt\n\n# Create an MTCNN detector instance\ndetector = MTCNN\n\n# Load the image\nimage_path = "frame_200.jpg"  # Replace with your image path\nimage = cv2.imread(image_path)\n\n# Check if the image was loaded\nif image is None:\n    print("Error: Image not loaded. Check the file path.")\n    exit()\n\n# Convert to RGB (MTCNN expects RGB images)\nimage_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)\n\n# Detect faces in the image\nresults = detector.detect_faces(image_rgb)\nprint(results)\n\n# Loop through detected faces\nfor result in results:\n    # Extract face bounding box\n    x, y, width, height = result["box"]\n    x2, y2 = x + width, y + height\n\n    # Draw bounding box around the face\n    cv2.rectangle(image, (x, y), (x2, y2), (255, 0, 0), 2)\n\n    # Extract and draw facial keypoints\n    keypoints = result["keypoints"]\n    for key, point in keypoints.items():\n        cv2.circle(image, tuple(point), 5, (0,
# ...

# %%
"""
from mtcnn import MTCNN

# Create an MTCNN detector instance
detector = MTCNN()

# Load and preprocess the image
image_path = "frame_200.jpg"  # Replace with your image path
image = cv2.imread(image_path)

# Check if the image was loaded
if image is None:
    print("Error: Image not loaded. Check the file path.")
    exit()

# Convert to RGB (MTCNN expects RGB images)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Detect faces in the image
results = detector.detect_faces(image_rgb)

"""
# Out:
# '\nfrom mtcnn import MTCNN\n\n# Create an MTCNN detector instance\ndetector = MTCNN()\n\n# Load and preprocess the image\nimage_path = "frame_200.jpg"  # Replace with your image path\nimage = cv2.imread(image_path)\n\n# Check if the image was loaded\nif image is None:\n    print("Error: Image not loaded. Check the file path.")\n    exit()\n\n# Convert to RGB (MTCNN expects RGB images)\nimage_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)\n\n# Detect faces in the image\nresults = detector.detect_faces(image_rgb)\n\n'

# %%
"""
if len(results) > 0:
    # Extract the first detected face
    face = results[0]

    # Extract eye landmarks
    left_eye = face['keypoints']['left_eye']
    right_eye = face['keypoints']['right_eye']

    print(f"Left Eye: {left_eye}, Right Eye: {right_eye}")
"""
# Out:
# '\nif len(results) > 0:\n    # Extract the first detected face\n    face = results[0]\n\n    # Extract eye landmarks\n    left_eye = face[\'keypoints\'][\'left_eye\']\n    right_eye = face[\'keypoints\'][\'right_eye\']\n\n    print(f"Left Eye: {left_eye}, Right Eye: {right_eye}")\n'

# %%
def get_eye_bounding_boxes(left_eye, right_eye, box_size=224):
    left_x, left_y = left_eye
    right_x, right_y = right_eye

    left_bbox = [left_x - box_size // 2, left_y - box_size // 2, 
                 left_x + box_size // 2, left_y + box_size // 2]
    right_bbox = [right_x - box_size // 2, right_y - box_size // 2, 
                  right_x + box_size // 2, right_y + box_size // 2]

    return left_bbox, right_bbox

# Calculate bounding boxes for eyes
# left_bbox, right_bbox = get_eye_bounding_boxes(left_eye, right_eye)
# print(f"Left Eye Bounding Box: {left_bbox}")
# print(f"Right Eye Bounding Box: {right_bbox}")

# %%
"""
import matplotlib.patches as patches

# Plot the image
fig, ax = plt.subplots(1)
ax.imshow(image)

# Draw bounding boxes
for (x1, y1, x2, y2) in [left_bbox, right_bbox]:
    rect = patches.Rectangle((x1, y1), x2 - x1, y2 - y1, linewidth=2, edgecolor='red', facecolor='none')
    ax.add_patch(rect)

plt.axis("off")
plt.show()
"""
# Out:
# '\nimport matplotlib.patches as patches\n\n# Plot the image\nfig, ax = plt.subplots(1)\nax.imshow(image)\n\n# Draw bounding boxes\nfor (x1, y1, x2, y2) in [left_bbox, right_bbox]:\n    rect = patches.Rectangle((x1, y1), x2 - x1, y2 - y1, linewidth=2, edgecolor=\'red\', facecolor=\'none\')\n    ax.add_patch(rect)\n\nplt.axis("off")\nplt.show()\n'

# %%
"""
import numpy as np

# Crop eye regions
left_eye_crop = image[left_bbox[1]:left_bbox[3], left_bbox[0]:left_bbox[2]]
right_eye_crop = image[right_bbox[1]:right_bbox[3], right_bbox[0]:right_bbox[2]]

# Show the cropped eyes
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(left_eye_crop)
plt.title("Left Eye")

plt.subplot(1, 2, 2)
plt.imshow(right_eye_crop)
plt.title("Right Eye")
plt.show()
"""
# Out:
# '\nimport numpy as np\n\n# Crop eye regions\nleft_eye_crop = image[left_bbox[1]:left_bbox[3], left_bbox[0]:left_bbox[2]]\nright_eye_crop = image[right_bbox[1]:right_bbox[3], right_bbox[0]:right_bbox[2]]\n\n# Show the cropped eyes\nplt.figure(figsize=(10, 5))\nplt.subplot(1, 2, 1)\nplt.imshow(left_eye_crop)\nplt.title("Left Eye")\n\nplt.subplot(1, 2, 2)\nplt.imshow(right_eye_crop)\nplt.title("Right Eye")\nplt.show()\n'

# %%
"""
right_eye_crop = cv2.cvtColor(right_eye_crop, cv2.COLOR_RGB2GRAY)
eye_resized = cv2.resize(right_eye_crop, (128, 128))

# Normalize and expand dimensions to match the model's input
eye_tensor = np.expand_dims(eye_resized, axis=(0, -1))  # Shape: (1, 128, 128, 1)
eye_tensor = eye_tensor.astype('float32') / 255.0  # Normalize to [0, 1]
# Predict using the pre-trained model
prediction = model.predict(eye_tensor)[0][0]  # Get the prediction

# Interpret the prediction
if prediction > 0.5:
    print("Right eye is open.")
else:
    print("Right eye is closed.")
    
"""
# Out:
# '\nright_eye_crop = cv2.cvtColor(right_eye_crop, cv2.COLOR_RGB2GRAY)\neye_resized = cv2.resize(right_eye_crop, (128, 128))\n\n# Normalize and expand dimensions to match the model\'s input\neye_tensor = np.expand_dims(eye_resized, axis=(0, -1))  # Shape: (1, 128, 128, 1)\neye_tensor = eye_tensor.astype(\'float32\') / 255.0  # Normalize to [0, 1]\n# Predict using the pre-trained model\nprediction = model.predict(eye_tensor)[0][0]  # Get the prediction\n\n# Interpret the prediction\nif prediction > 0.5:\n    print("Right eye is open.")\nelse:\n    print("Right eye is closed.")\n    \n'

# %%
import cv2
from mtcnn import MTCNN
import numpy as np

def process_video(video_path, output_path, model, detector, closed_frame_threshold=30):
    """
    Processes a video to detect drowsiness by analyzing eye closure frames using MTCNN and a CNN model.

    Args:
        video_path (str): Path to the input video.
        output_path (str): Path to save the processed video.
        model: Trained CNN model for eye state classification.
        detector: MTCNN face and landmark detector.
        closed_frame_threshold (int): Threshold of consecutive frames with closed eyes to trigger an alert.
    """
    cap = cv2.VideoCapture(video_path)
    closed_frames = 0  # Count of consecutive frames with closed eyes
    fps = int(cap.get(cv2.CAP_PROP_FPS))  # Frames per second of the video

    # Video writer setup
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, fourcc, int(cap.get(cv2.CAP_PROP_FPS)), 
                          (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
            
        # Convert frame to RGB (MTCNN expects RGB images)
        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Detect faces and landmarks
        detections = detector.detect_faces(image_rgb)

        eye_closed = False  # Flag to check if any eye is closed in the current frame

        for detection in detections:
            # Extract face bounding box
            x, y, width, height = detection['box']
            x, y = max(0, x), max(0, y)  # Ensure bounding box is within frame bounds

            # Draw rectangle around the face
            cv2.rectangle(frame, (x, y), (x + width, y + height), (255, 0, 0), 2)

            # Extract eye landmarks
            keypoints = detection['keypoints']
            left_eye = keypoints['left_eye']
            right_eye = keypoints['right_eye']

            # Define bounding boxes for eyes
            left_bbox, right_bbox = get_eye_bounding_boxes(left_eye, right_eye)

            # Extract and preprocess eye regions
            for bbox in [left_bbox, right_bbox]:
                x1, y1, x2, y2 = bbox
                eye_region = frame[y1:y2, x1:x2]

                # Preprocess eye region for model prediction
                eye_region_resized = cv2.resize(eye_region, (128, 128))  # Resize to model input size
                eye_region_gray = cv2.cvtColor(eye_region_resized, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
                eye_region_normalized = eye_region_gray / 255.0  # Normalize
                eye_region_input = np.expand_dims(eye_region_normalized, axis=(0, -1))  # Add batch and channel dims

                # Predict eye state (1 = open, 0 = closed)
                prediction = model.predict(eye_region_input)
                if prediction[0] < 0.5:  # Threshold for closed eyes
                    eye_closed = True
                    break  # Exit early if any eye is closed

        # Handle drowsiness detection based on eye state
        if eye_closed:
            closed_frames += 1
            if closed_frames > closed_frame_threshold:
                cv2.putText(frame, "DROWSY!", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 0, 255), 3)
        else:
            cv2.putText(frame, f"Closed Time: {closed_frames / fps:.2f}s", (50, 300), 
                    cv2.FONT_HERSHEY_SIMPLEX, 3, (255, 255, 255), 3)
            closed_frames = 0
            

        # Write the processed frame to output video
        out.write(frame)

    # Release resources
    cap.release()
    out.release()

# %%
from mtcnn import MTCNN

# Create an MTCNN detector instance
detector = MTCNN()

output_path = "processed_output.avi"  # Output file path
process_video(video_path, output_path, model, detector)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732027450.351944      65 service.cc:145] XLA service 0x7a65c4005bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732027450.352009      65 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# I0000 00:00:1732027451.625140      65 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ...
